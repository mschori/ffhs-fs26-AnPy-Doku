# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing()

Integral(sqrt(1/x), x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡

# %%
print(latex(Integral(sqrt(1/x), x)))
# Out:
# \int \sqrt{\frac{1}{x}}\, dx

# %%
limit(sin(x)/x, x, 0)

expr = Limit((cos(x) -1 )/x, x, 0)

expr
# Out:
#      ⎛cos(x) - 1⎞
#  lim ⎜──────────⎟
# x─→0⁺⎝    x     ⎠
