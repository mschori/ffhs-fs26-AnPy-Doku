# %% [markdown]
# Aufgabe der Differenzialrechnung: Steigung berechnen. Ableitung von $f(x)$ berechnen.
#
# Aufgabe der Integralrechnung: Stammfunktion bilden. Integral von f(x) berechnen.
# --> so, dass $F'(x)=f(x)$ gilt.
#
# --> auch Aufleiten genannt.
#
# ---
#
# f(x) = Integrand
#
# Stammfunktion F(x) = Aufleitung von f(x)
#
# x = Integrationsvariable
#
# dx = Differential
